# %% [markdown]
# # **2024(R6)年度 機械学習**
# # **第2週　線形モデルによるクラス分類**
# ## 非線形サポートベクトルマシン(Linear Support Vector Machine; SVM)
# ©️小林 邦和＠愛知県立大学 情報科学部
# Date: October 10, 2023

# %% [markdown]
# # **準備**

# %% [markdown]
# ## 警告の非表示(必要に応じて実行，Google Colabでは不要)

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Google Driveのマウント(必要に応じて実行)

# %%
# if str(get_ipython()).startswith("<google.colab."):
#     from google.colab import drive
#     drive.mount('/content/drive')

# %% [markdown]
# ## 日本語化Matplotlib(必要に応じて実行)

# %%
# if str(get_ipython()).startswith("<google.colab."):
#     !pip install japanize-matplotlib

# %% [markdown]
# ## 各種ライブラリの読み込み

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# グラフ表示で日本語を使う場合，以下2行は必須
# import japanize_matplotlib
# japanize_matplotlib.japanize()

# %% [markdown]
# ## フラグ設定

# %%
# 使用するSVMモデルのコメントを外し，使用しないものはコメントアウト
model_flag = 0 # ハードマージン線形SVM
#model_flag = 1 # ソフトマージン線形SVM

# %% [markdown]
# # **データの準備**

# %% [markdown]
# ## **ガウス分布状N次元データ**
# ### **make_blobs**
# 引数
# *   n_samples：データの個数
# *   n_features：特徴量の数
# *   centers：塊の数
# *   cluster_std：ばらつきの大きさ(標準偏差)
# *   random_state：乱数生成のシード値(同じ値の設定で再現性の確保)
#
# 戻り値
# *   入力データ(n_samples x n_features)
# *   出力データ(n_samples)

# %% [markdown]
# ## **データの生成**
# 特徴量が2種類(2次元)，塊が2個(2クラス)，標準偏差が1の300個のデータセット

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(
    n_samples=300,
    n_features=2,
    centers=[[1,1],[-1,-1]],
#    centers=[[1,1],[0,0],[-1,-1]],
#    centers=2,
#    centers=3,
    cluster_std=0.5,
#    cluster_std=0.2,
#    cluster_std=0.9,
    random_state=3)

# 特徴量(X)でデータフレームを作成し，クラス(y)をClassの列として追加
df = pd.DataFrame(X)
df.rename(columns={0: "X1", 1: "X2"}, inplace=True)
df["Class"] = y
df.head()
# Out:
#          X1        X2  Class
# 0 -0.907366 -1.211396      1
# 1  2.355963  1.313737      0
# 2  0.698557  0.042764      0
# 3 -0.721779 -0.626554      1
# 4 -0.856158 -0.016763      1

# %% [markdown]
# ## **データの散布図**
# 特徴量X1を横軸に，特徴量X2を縦軸にして，Classの値で色分けをした散布図の描画

# %%
# クラス0は青，クラス1は橙で散布図を描画
sns.scatterplot(x="X1", y="X2", hue="Class", data=df)
plt.title("Dataset")
#plt.title("データセット")
plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.grid()
plt.show()

# %% [markdown]
# # **データの分割(訓練用とテスト用)**
# ### **train_test_split**
# 引数
# *   test_size：テストデータのサイズ指定(0〜1.0)
# *   train_size：訓練データのサイズ指定(0〜1.0)
# *   random_state：乱数生成のシード値
#
# 戻り値
# *   X_train：訓練用入力データ
# *   y_train：訓練用出力データ
# *   X_test：テスト用入力データ
# *   y_test：テスト用出力データ

# %%
# 訓練データとテストデータへ分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# テストデータに2つの外れ値の設定
import numpy as np
X_test[0] = np.array([[1,0]])
y_test[0] = 1
X_test[1] = np.array([[0,0]])
y_test[1] = 0

# 訓練用の特徴量(X_train)でデータフレームを作成し，クラス(y_train)をClassの列として追加
df_train = pd.DataFrame(X_train)
df_train.rename(columns={0: "X1", 1: "X2"}, inplace=True)
df_train["Class"] = y_train
df_train["Usage"] = "Training Data"

# テスト用の特徴量(X_test)でデータフレームを作成し，クラス(y_test)をClassの列として追加
df_test = pd.DataFrame(X_test)
df_test.rename(columns={0: "X1", 1: "X2"}, inplace=True)
df_test["Class"] = y_test
df_test["Usage"] = "Test Data"

# 訓練用とテスト用のデータを結合
df = pd.concat([df_train, df_test])

# クラス0は青，クラス1は橙，訓練用はO，テスト用はXで散布図を描画
sns.scatterplot(x="X1", y="X2", hue="Class", style="Usage", data=df)
plt.title("Training data and test data")
# plt.title("訓練データとテストデータ")
plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.grid()
plt.show()

# %% [markdown]
# # **モデルの学習**
# ## **線形SVM**(Support Vector Machine)
# ### **使用モデル一覧**
# *   ハードマージン線形SVM
# *   ソフトマージン線形SVM
#
# ### **SVC** サポートベクトル分類のクラス
# 引数
# *   kernel：カーネル関数(線形SVMの場合，'linear'を指定)
# *   C：正規化係数(C>0)
#     *   小さな値の場合，ソフトマージン型
#     *   大きな値の場合，ハードマージン型
#
# ### **fit** モデルの訓練のための関数(メソッド)
# 引数
# *   X：入力データ
# *   y：出力データ

# %%
from sklearn.svm import SVC

# SVMによる学習モデルの作成
match model_flag:
    case 0:
        model = SVC(kernel='linear', C=100) # ハードマージン線形SVM(可能な限り大きなCの値)
        print("ハードマージン線形SVM")
    case 1:
        model = SVC(kernel='linear', C=1) # ソフトマージン線形SVM
        print("ソフトマージン線形SVM")

# 訓練データを用いた学習
model.fit(X_train, y_train)
# Out:
# ハードマージン線形SVM
# SVC(C=100, kernel='linear')

# %% [markdown]
# # **学習済みモデルのテスト**
# ### **predict**　学習済モデルのテストのための関数(メソッド)
# 引数
# *   y：出力データ
#
# 戻り値
# *   予測値

# %%
# テストデータを用いた予測
pred_test = model.predict(X_test)

# テスト用の特徴量(X_test)でデータフレームを作成し，クラスの予測結果(pred)をPredictionの列として追加
df_test["Prediction"] = pred_test

# 正解のクラス0は青，クラス1は橙，予測のクラス0はO，クラス1はXで散布図を描画
sns.scatterplot(x="X1", y="X2", hue="Class", style="Prediction", data=df_test)
plt.title("Prediction results by the trained model")
#plt.title("学習済モデルの予測結果")
plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.grid()
plt.show()

# %% [markdown]
# # **モデルの性能評価**

# %% [markdown]
# ## **正解率の計算**
# ### **accuracy_score**　正解率の計算のための関数(メソッド)
# 引数
# *   X：テスト用入力データ
# *   y：テスト用出力データ
#
# 戻り値
# *   正解率

# %%
from sklearn.metrics import accuracy_score

# 正解率の計算(テストデータ)
score = accuracy_score(y_test, pred_test)
print("正解率 = {0:5.1f}%".format(score*100))
# Out:
# 正解率 =  97.3%

# %% [markdown]
# ## **混同行列の計算**
# ### **accuracy_score**
# 引数
# *   y：正解値
# *   pred：予測値
#
# 戻り値
# *   混同行列

# %%
from sklearn.metrics import confusion_matrix

# 混同行列の計算(テストデータ)
print("混同行列=\n{0}".format(confusion_matrix(y_test, pred_test)))
# Out:
# 混同行列=
# [[41  0]
#  [ 2 32]]

# %% [markdown]
# ## **決定境界の描画**
# ### **plot_boundary**
# 引数
# *   clf：モデル
# *   X：第1特徴量
# *   Y：第2特徴量
# *   target：予測値
# *   xlabel：横軸のラベル
# *   ylabel：縦軸のラベル

# %%
# 散布図に決定境界を描画する関数
from matplotlib.colors import ListedColormap
def plot_boundary(model, X, Y, target, xlabel, ylabel):
    # 点と塗り潰しのカラーマップ
    cmap_dots = ListedColormap([ "#1f77b4", "#ff7f0e", "#2ca02c"])
    cmap_fills = ListedColormap([ "#c6dcec", "#ffdec2", "#cae7ca"])

    # モデルがあれば，表示範囲の点をすべて予測して色を塗る
    if model:
        # 表示範囲を少し広げて分割し，調べる点(200x200)を用意
        XX, YY = np.meshgrid(
            np.linspace(X.min()-1, X.max()+1, 200),
            np.linspace(Y.min()-1, Y.max()+1, 200))
        # すべての点の値をモデルで予測
        pred = model.predict(np.c_[XX.ravel(), YY.ravel()]).reshape(XX.shape)
        #　予測結果の値(0〜2)の色(cmap_fills)で塗りつぶす
        plt.pcolormesh(XX, YY, pred, cmap=cmap_fills, shading="auto")
        #　境界を灰色で塗る
        plt.contour(XX, YY, pred, colors="gray")
    #　targetの値(0〜2)の色(cmap_dots)で点を描画
    plt.scatter(X, Y, c=target, cmap=cmap_dots)
    plt.title("Decision Boundary")
    # plt.title("決定境界")
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()

# 決定境界の描画
plot_boundary(model, df_test["X1"], df_test["X2"], pred_test, "$X_1$", "$X_2$")

# %% [markdown]
# ## **決定境界とサポートベクトルの描画**
# ### **plot_svc_decision_boundary**
# 引数
# *   clf：モデル
# *   x_min：横軸の最小値
# *   x_max：横軸の最大値

# %%
# 決定境界とサポートベクトルの描画
def plot_svc_decision_boundary(svm_clf, xmin, xmax):
    w = svm_clf.coef_[0]
    b = svm_clf.intercept_[0]

    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 500)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = svm_clf.support_vectors_
    plt.scatter(svs[:, 0], svs[:, 1], s=180, facecolors='#FFAAAA')
    plt.plot(x0, decision_boundary, "k-", linewidth=2)
    plt.plot(x0, gutter_up, "k--", linewidth=2)
    plt.plot(x0, gutter_down, "k--", linewidth=2)

# 決定境界とサポートベクトルの描画
plot_svc_decision_boundary(model, -2.5, 2.5)

# クラス0は青，クラス1は橙，訓練用はO，テスト用はXで散布図を描画
sns.scatterplot(x="X1", y="X2", hue="Class", style="Usage", data=df)
plt.title("Decision boundary (solid line) and support vectors")
# plt.title("決定境界(実線)とサポートベクトル")
plt.xlabel("$X_1$")
plt.ylabel("$X_2$")
plt.legend(loc="lower right")
plt.grid()
plt.show()

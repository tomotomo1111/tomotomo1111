# %%
import numpy as np
from scipy.integrate import odeint

M = 1
l = 0.5
J = 1
c = 0.42
ga = 9.81

t0 = 0
dt = 0.01
tf = 10

x0 = np.array([np.pi/2, 0])

kp = 1
kd = 1

nls = ode( @(t,x) pend_nlnsys(t,x), np.arange(t0, tf, dt), x0 );
#u4nls = arrayfun(@(t,x1,x2) ux(t,[x1;x2]), nls[0], nls[1][1], nls[1][2]);

def ux(t, x):
    #u = 0*t
    u = np.dot([-kp, -kd], x)
    return u

def pend_nlnsys(t, x):
    return 

def pend_alnsys(t, x):
    return np.dot(A, x) + np.dot(B, ux(t, x))
# Out:
#   File "<ipython-input-1-22e4e3761158>", line 19
#     [t4nls, x4nls] = ode( @(t,x) pend_nlnsys(t,x), np.arange(t0, tf, dt), x0 );
#                           ^
# SyntaxError: invalid syntax
